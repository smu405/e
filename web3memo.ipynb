# %%
C:\Users\jsl\Code\git\bb\jsl\bitcoin\myWinHere>node
> var Web3 = require('web3')
undefined
> var web3 = new Web3('http://localhost:8545');
undefined
> web3.eth.getCoinbase().then(console.log)
Promise {
  <pending>,
  domain:
   Domain {
     domain: null,
     _events:
      [Object: null prototype] {
        removeListener: [Function: updateExceptionCapture],
        newListener: [Function: updateExceptionCapture],
        error: [Function: debugDomainError] },
     _eventsCount: 3,
     _maxListeners: undefined,
     members: [] } }
> 0xffd4377c45e6bab80008a78cac0140078da25b63

> web3.eth.getChainId().then(console.log)
Promise {
  <pending>,
  domain:
   Domain {
     domain: null,
     _events:
      [Object: null prototype] {
        removeListener: [Function: updateExceptionCapture],
        newListener: [Function: updateExceptionCapture],
        error: [Function: debugDomainError] },
     _eventsCount: 3,
     _maxListeners: undefined,
     members: [] } }
> 33

> web3.eth.getAccounts(console.log)
Promise {
  <pending>,
  domain:
   Domain {
     domain: null,
     _events:
      [Object: null prototype] {
        removeListener: [Function: updateExceptionCapture],
        newListener: [Function: updateExceptionCapture],
        error: [Function: debugDomainError] },
     _eventsCount: 3,
     _maxListeners: undefined,
     members: [] } }
> null [ '0xffd4377c45e6BAb80008a78Cac0140078Da25b63',
  '0xfcAcc5E428b9A61cAb0Ed08515A8EF30d3e85ED2' ]




> web3.eth.getCoinbase().then(console.log)
Promise {
  <pending>,
  domain:
   Domain {
     domain: null,
     _events:
      [Object: null prototype] {
        removeListener: [Function: updateExceptionCapture],
        newListener: [Function: updateExceptionCapture],
        error: [Function: debugDomainError] },
     _eventsCount: 3,
     _maxListeners: undefined,
     members: [] } }
> 0xffd4377c45e6bab80008a78cac0140078da25b63



> web3.eth.getBlockNumber().then(console.log)
Promise {
  <pending>,
  domain:
   Domain {
     domain: null,
     _events:
      [Object: null prototype] {
        removeListener: [Function: updateExceptionCapture],
        newListener: [Function: updateExceptionCapture],
        error: [Function: debugDomainError] },
     _eventsCount: 3,
     _maxListeners: undefined,
     members: [] } }
> 1007


> web3.eth.getBalance('0xffd4377c45e6BAb80008a78Cac0140078Da25b63').then(console.log)
Promise {
  <pending>,
  domain:
   Domain {
     domain: null,
     _events:
      [Object: null prototype] {
        removeListener: [Function: updateExceptionCapture],
        newListener: [Function: updateExceptionCapture],
        error: [Function: debugDomainError] },
     _eventsCount: 3,
     _maxListeners: undefined,
     members: [] } }
> 5047968750000000000000


> web3.eth.getNodeInfo().then(console.log)
Promise {
  <pending>,
  domain:
   Domain {
     domain: null,
     _events:
      [Object: null prototype] {
        removeListener: [Function: updateExceptionCapture],
        newListener: [Function: updateExceptionCapture],
        error: [Function: debugDomainError] },
     _eventsCount: 3,
     _maxListeners: undefined,
     members: [] } }
> Geth/v1.8.20-stable-24d727b6/windows-amd64/go1.11.2

# %%
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

# %%
1주
- 자바가 언제 처음 나왔는지?
    - 썬 마이크로시스템즈 Sun 에서 1995년 발표
    - 2009년 이후 오라클에서 개발을 이어나가고 있어요
- 처음에 어떤 용도로 개발된 언어?
    - 가전제품, 임베디드 목적으로 개발
- 현재는 주로 어떤 분야에 많이 사용?
    기업에서 웹기반 시스템에 많이 사용.
- 자바는 어떤 지향언어?
    객체지향 언어
    자바는 순수객체지향, C++는 객체지향 기법을 사용하지 않아도 가능
- 자바가 WORA (Write Once, Run Anywhere)인 이유, 즉 한 번 개발되면 어디에나 실행가능
    - 바이트코드로 변환되어 JVM에서 실행되기 때문에
- 자바는 메모리를 할당하고 반환하는 프로그래밍 언어인가?
    - 메모리 할당, 회수를 하지 않아도 되는 프로그램.
    - 포인터를 사용하지도 않음.
- JRE와 JDK 차이는?
    JRE는 자바실행환경 Java Runtime Environment - JVM을 포함, 자바를 실행하는 환경을 제공
    JDK는 자바개발도구 Java Development Kit - JRE + javac, java 등 개발에 필요한 도구 포함
- OpenJDK 오픈소스를 사용해도 됨
- Java SE 데스크탑용
- Java EE 비지니스 소프트웨어 개발용
- 프로그래밍이란 코딩을 말하는지?
    - 좁게 보면 코딩
    - 넓게 보면 프로그래밍은 컴퓨터 또는 유사 기기에서 동작할 프로그램의 요구사항을 파악하고, 설계하고, 구현 및 검수하는 과정
- 객체지향 자바가 컴퓨터에서 실행하는 단위? 객체
- 클래스를 구성하는 2가지 요소는?
    - 데이터와 함수로 구성이 되었다
- 객체지향에서는 재사용이 중요
- Hello World 프로그램 만들고, 컴파일 및 실행해보았는지
- 자바의 설치? 버전은?
- 폴더 구성
    src
    classes
    lib
- src에는 어떤 파일을 저장
- classes에는 어떤 파일을 저장
- javac, java
javac -d classes -sourcepath src src\Hello.java
java -cp classes Hello
- jshell
    - /set editor -retain -wait "c:\\..."
- 왜 백슬래시 2개 쓰는지?
- /edit 번호 명령어
- /env -class-path 디렉토리
- intellij
